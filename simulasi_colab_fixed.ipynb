# %% [markdown]
# # 🚗 SIMULASI PREDIKSI TARIF PARKIR PROGRESIF
# ## Menggunakan Random Forest untuk Optimasi Tarif di Kota Banyumas
#
# **Notebook ini dirancang khusus untuk Google Colab dengan urutan SPASIAL dulu, SIMULASI kedua**
#
# ✅ Mount Google Drive (akses file data)
# ✅ Install library otomatis
# ✅ Data loading & exploration
# ✅ Data cleaning & preprocessing
# ✅ Feature engineering & model training
# ✅ Model evaluation
# ✅ Feature importance analysis
# ✅ **Spatial analysis (Folium map 407 markers)** - SECTION 10 ✨
# ✅ **Interactive simulation (unlimited input)** - SECTION 11 ✨
# ✅ Export results to Excel
#
# **Waktu eksekusi:** ~5-10 menit
